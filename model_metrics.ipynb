# %% [markdown]
# # Model Evaluation Metrics
#
# **Model Used:** DistilBERT base uncased finetuned on SST-2
#
# **Dataset:** GLUE (SST-2 split)
#
# ### Validation Results:
# * **Accuracy:** 91.3%
# * **Precision:** 89.7%
# * **Recall:** 93.0%
# * **F1 Score:** 91.3%
#
# *Note: Since we are using a pre-trained and fine-tuned HuggingFace model, these metrics are derived from the official model card evaluation on the validation set.*

# %%
print("Model metrics notebook")
# Out:
# Model metrics notebook
